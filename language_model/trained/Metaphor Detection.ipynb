# %%
from koalanlp.Util import initialize, finalize
from koalanlp.proc import Parser
from koalanlp import API

initialize(KKMA='LATEST')  #: HNN=2.0.4, ETRI=2.0.4

parser = Parser(API.KKMA)

while True:
    text = input("분석할 문장을 입력하세요>> ").strip()

    if len(text) == 0:
        break

    sentences = parser(text)

    for sent in sentences:
        print("===== Sentence =====")
        print(sent.singleLineString())
        print("# Dependency Parse result")

        dependencies = sent.getDependencies()
        if len(dependencies) > 0:
            for edge in dependencies:
                print("[%s]는 [%s]의 %s-%s" % (edge.getDependent().getSurface(),
                                             edge.getGovernor().getSurface() if edge.getGovernor() is not None else "ROOT",
                                             str(edge.getType()),
                                             str(edge.getDepType())))
        else:
            print("(Unexpected) NULL!")

finalize()
# Out:
# [koalanlp.jip] [INFO] Latest version of kr.bydelta:koalanlp-kkma (2.1.4) will be used.
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\net\sf\py4j\py4j\0.10.8.1\py4j-0.10.8.1.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\net\sf\py4j\py4j\0.10.8.1\py4j-0.10.8.1.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\net\sf\py4j\py4j\0.10.8.1\py4j-0.10.8.1.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\net\sf\py4j\py4j\0.10.8.1\py4j-0.10.8.1.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/net/sf/py4j/py4j/0.10.8.1/py4j-0.10.8.1.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\sonatype\oss\oss-parent\7\oss-parent-7.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\sonatype\oss\oss-parent\7\oss-parent-7.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\sonatype\oss\oss-parent\7\oss-parent-7.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\sonatype\oss\oss-parent\7\oss-parent-7.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/sonatype/oss/oss-parent/7/oss-parent-7.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\kr\bydelta\koalanlp-kkma\2.1.4\koalanlp-kkma-2.1.4.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\kr\bydelta\koalanlp-kkma\2.1.4\koalanlp-kkma-2.1.4.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\kr\bydelta\koalanlp-kkma\2.1.4\koalanlp-kkma-2.1.4.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\kr\bydelta\koalanlp-kkma\2.1.4\koalanlp-kkma-2.1.4.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-kkma/2.1.4/koalanlp-kkma-2.1.4.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\kr\bydelta\koalanlp-core\2.1.4\koalanlp-core-2.1.4.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\kr\bydelta\koalanlp-core\2.1.4\koalanlp-core-2.1.4.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\kr\bydelta\koalanlp-core\2.1.4\koalanlp-core-2.1.4.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\kr\bydelta\koalanlp-core\2.1.4\koalanlp-core-2.1.4.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-core/2.1.4/koalanlp-core-2.1.4.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-jdk8\1.3.50\kotlin-stdlib-jdk8-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-jdk8\1.3.50\kotlin-stdlib-jdk8-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-jdk8\1.3.50\kotlin-stdlib-jdk8-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-jdk8\1.3.50\kotlin-stdlib-jdk8-1.3.50.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk8/1.3.50/kotlin-stdlib-jdk8-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-jdk7\1.3.50\kotlin-stdlib-jdk7-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-jdk7\1.3.50\kotlin-stdlib-jdk7-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-jdk7\1.3.50\kotlin-stdlib-jdk7-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-jdk7\1.3.50\kotlin-stdlib-jdk7-1.3.50.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk7/1.3.50/kotlin-stdlib-jdk7-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib\1.3.50\kotlin-stdlib-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib\1.3.50\kotlin-stdlib-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib\1.3.50\kotlin-stdlib-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib\1.3.50\kotlin-stdlib-1.3.50.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib/1.3.50/kotlin-stdlib-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\jetbrains\annotations\13.0\annotations-13.0.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\jetbrains\annotations\13.0\annotations-13.0.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\jetbrains\annotations\13.0\annotations-13.0.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\jetbrains\annotations\13.0\annotations-13.0.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/jetbrains/annotations/13.0/annotations-13.0.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-common\1.3.50\kotlin-stdlib-common-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.m2\repository\org\jetbrains\kotlin\kotlin-stdlib-common\1.3.50\kotlin-stdlib-common-1.3.50.pom
# [koalanlp.jip] [Checking] pom file C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-common\1.3.50\kotlin-stdlib-common-1.3.50.pom
# [koalanlp.jip] [Skipped] pom file not found at C:\Users\bber2012\.ivy2\cache\org\jetbrains\kotlin\kotlin-stdlib-common\1.3.50\kotlin-stdlib-common-1.3.50.pom
# [koalanlp.jip] [Checking] pom file https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-common/1.3.50/kotlin-stdlib-common-1.3.50.pom
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/net/sf/py4j/py4j/0.10.8.1/py4j-0.10.8.1.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-kkma/2.1.4/koalanlp-kkma-2.1.4-assembly.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-core/2.1.4/koalanlp-core-2.1.4.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk8/1.3.50/kotlin-stdlib-jdk8-1.3.50.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk7/1.3.50/kotlin-stdlib-jdk7-1.3.50.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib/1.3.50/kotlin-stdlib-1.3.50.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/org/jetbrains/annotations/13.0/annotations-13.0.jar
# [koalanlp.jip] [Downloading] jar from https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-common/1.3.50/kotlin-stdlib-common-1.3.50.jar
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/net/sf/py4j/py4j/0.10.8.1/py4j-0.10.8.1.jar 122939 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/net/sf/py4j/py4j/0.10.8.1/py4j-0.10.8.1.jar completed in 2.120568 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-core/2.1.4/koalanlp-core-2.1.4.jar 247555 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-core/2.1.4/koalanlp-core-2.1.4.jar completed in 2.383861 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk8/1.3.50/kotlin-stdlib-jdk8-1.3.50.jar 15476 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk8/1.3.50/kotlin-stdlib-jdk8-1.3.50.jar completed in 1.845606 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk7/1.3.50/kotlin-stdlib-jdk7-1.3.50.jar 3129 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-jdk7/1.3.50/kotlin-stdlib-jdk7-1.3.50.jar completed in 1.686969 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/org/jetbrains/annotations/13.0/annotations-13.0.jar 17536 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/org/jetbrains/annotations/13.0/annotations-13.0.jar completed in 1.857246 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib/1.3.50/kotlin-stdlib-1.3.50.jar 1326269 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib/1.3.50/kotlin-stdlib-1.3.50.jar completed in 3.523255 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-common/1.3.50/kotlin-stdlib-common-1.3.50.jar 170934 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/org/jetbrains/kotlin/kotlin-stdlib-common/1.3.50/kotlin-stdlib-common-1.3.50.jar completed in 2.138117 secs
# [koalanlp.jip] [Downloading] https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-kkma/2.1.4/koalanlp-kkma-2.1.4-assembly.jar 8035057 bytes to download
# [koalanlp.jip] [Downloading] Download https://oss.sonatype.org/content/repositories/public/kr/bydelta/koalanlp-kkma/2.1.4/koalanlp-kkma-2.1.4-assembly.jar completed in 42.401724 secs
# [koalanlp.jip] JVM initialization procedure is completed.
# 분석할 문장을 입력하세요>> 말뚝처럼 굳어진 제임스와 배달환이 벙해진 눈길로 바랬다.
# ===== Sentence =====
# 말뚝/NNG+처럼/JKB 굳어지/VV+ㄴ/ETM 제임스/NNG+와/JKB 배달/NNG 환/NNM+이/JKS 벙/NF+하/XSV+어/EC 지/VX+ㄴ/ETM 눈길/NNG+로/JKB 바래/VV+었/EP+다/EF+./SF
# # Dependency Parse result
# [바랬다.]는 [ROOT]의 X-UNDEF
# [눈길로]는 [바랬다.]의 NP-AJT
# [진]는 [눈길로]의 DP-MOD
# [벙해]는 [진]의 VP-CNJ
# [제임스와]는 [벙해]의 NP-AJT
# [굳어진]는 [제임스와]의 DP-MOD
# [말뚝처럼]는 [굳어진]의 NP-AJT
# [환이]는 [벙해]의 NP-SBJ
# [배달]는 [환이]의 NP-None
